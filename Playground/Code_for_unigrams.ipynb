# %%
from collections import defaultdict
import math
trainDict = defaultdict(list)

# %%
#Sample from the training set
trainDict = {'en': ['im confused what is the real justin justinbieber jbbstratfordboy jdbstratfordboy', 'just posted a photo  pamplona spain httptcoqdaqazsb', 'alinazasoro have a very good day asieryou know that you can get a very good marc'],
             'es': ['pedazo de tarta k me e kurrao ske k buena soy en todo lo k hago jajajajaja httptcooeslfdxl', 'no hace falta que te digan que vas a morir para empezar a vivir'],
             'ca': ['joseepcoll saps q si primo arraun remo illunbe trintxerpe et fotr una pallissota quan vengui per pascu arrebet '], 
             'eu': ['anderruiz  barkauu nere', 'aitorlakun inbidi pixkat eman beharko zaizu ordun p jojojojo']}

# %%
enDict = {}
esDict = {}
euDict = {}
caDict = {}
ptDict = {}
glDict = {}
for key, value in trainDict.items():
    #get the dictionary corresponding to the language(key)
    charCount = 0
    if 'en' in key:
        for eachTweet in value:
            for eachChar in eachTweet:
                if not eachChar.isspace():
                    if eachChar in enDict:
                        count = enDict[eachChar]
                        count += 1
                        enDict[eachChar] = count
                        charCount += 1
                        # increase the counter for that character
                    else:
                        enDict[eachChar] = 1
                        charCount += 1
                        # add the entry to the dictionary and set count to 1
#         enDict['charCount'] = charCount
        enDict = {k: (v/charCount) for k, v in enDict.items()}
#         enDict = {k: math.log10(v / charCount) for k, v in enDict.items()}
#         for ken, ven in enDict.items():
#             value = enDict[ken]
#             valuelog = math.log10(value)
#             enDict[ken] = valuelog
    elif 'es' in key:
        for eachTweet in value:
            for eachChar in eachTweet:
                if not eachChar.isspace():
                    if eachChar in esDict:
                        count = esDict[eachChar]
                        count += 1
                        esDict[eachChar] = count
                        charCount += 1
                        # increase the counter for that character
                    else:
                        esDict[eachChar] = 1
                        charCount += 1
                        # add the entry to the dictionary and set count to 1
#         esDict['charCount'] = charCount
        esDict = {k: (v/charCount) for k, v in esDict.items()}
#         esDict = {k: math.log10(v / charCount) for k, v in esDict.items()}
#         for ken, ven in esDict.items():
#             value = esDict[ken]
#             valuelog = math.log10(value)
#             esDict[ken] = valuelog
    elif 'eu' in key:
        for eachTweet in value:
            for eachChar in eachTweet:
                if not eachChar.isspace():
                    if eachChar in euDict:
                        count = euDict[eachChar]
                        count += 1
                        euDict[eachChar] = count
                        charCount += 1
                        # increase the counter for that character
                    else:
                        euDict[eachChar] = 1
                        charCount += 1
                        # add the entry to the dictionary and set count to 1
#         euDict['charCount'] = charCount
        euDict = {k: (v/charCount) for k, v in euDict.items()}
#         euDict = {k: math.log10(v / charCount) for k, v in euDict.items()}
#         for ken, ven in euDict.items():
#             value = euDict[ken]
#             valuelog = math.log10(value)
#             euDict[ken] = valuelog
    elif 'ca' in key:
        for eachTweet in value:
            for eachChar in eachTweet:
                if not eachChar.isspace():
                    if eachChar in caDict:
                        count = caDict[eachChar]
                        count += 1
                        caDict[eachChar] = count
                        charCount += 1
                        # increase the counter for that character
                    else:
                        caDict[eachChar] = 1
                        charCount += 1
                        # add the entry to the dictionary and set count to 1
#         caDict['charCount'] = charCount
        caDict = {k: (v/charCount) for k, v in caDict.items()}
#         caDict = {k: math.log10(v / charCount) for k, v in caDict.items()}
#         for ken, ven in caDict.items():
#             value = caDict[ken]
#             valuelog = math.log10(value)
#             caDict[ken] = valuelog
    elif 'pt' in key:
        for eachTweet in value:
            for eachChar in eachTweet:
                if not eachChar.isspace():
                    if eachChar in ptDict:
                        count = ptDict[eachChar]
                        count += 1
                        ptDict[eachChar] = count
                        charCount += 1
                        # increase the counter for that character
                    else:
                        ptDict[eachChar] = 1
                        charCount += 1
                        # add the entry to the dictionary and set count to 1
#         ptDict['charCount'] = charCount
        ptDict = {k: (v/charCount) for k, v in ptDict.items()}
#         ptDict = {k: math.log10(v / charCount) for k, v in ptDict.items()}
#         for ken, ven in ptDict.items():
#             value = ptDict[ken]
#             valuelog = math.log10(value)
#             ptDict[ken] = valuelog
    elif 'gl' in key:
        for eachTweet in value:
            for eachChar in eachTweet:
                if not eachChar.isspace():
                    if eachChar in glDict:
                        count = glDict[eachChar]
                        count += 1
                        glDict[eachChar] = count
                        charCount += 1
                        # increase the counter for that character
                    else:
                        glDict[eachChar] = 1
                        charCount += 1
                        # add the entry to the dictionary and set count to 1
#         glDict['charCount'] = charCount
        glDict = {k: (v/charCount) for k, v in glDict.items()}
#         glDict = {k: math.log10(v / charCount) for k, v in glDict.items()}
#         for ken, ven in glDict.items():
#             value = glDict[ken]
#             valuelog = math.log10(value)
#             glDict[ken] = valuelog

# %%
enDict = {k: math.log10(v / charCount) for k, v in enDict.items()}
print(enDict)

# %%
esDict = {k: math.log10(v / charCount) for k, v in esDict.items()}
print(esDict)

# %%
euDict = {k: math.log10(v / charCount) for k, v in euDict.items()}
print(euDict)

# %%
caDict = {k: math.log10(v / charCount) for k, v in caDict.items()}
print(caDict)

# %%
ptDict = {k: math.log10(v / charCount) for k, v in ptDict.items()}
print(ptDict)

# %%
glDict = {k: math.log10(v / charCount) for k, v in glDict.items()}
print(glDict)
