# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dict0 = {'I'  :  0,
'M'  :  1,
'C'  :  2,
'O'  :  3,
'N'  :  4,
'F'  :  5,
'U'  :  6,
'S'  :  7,
'E'  :  8,
'D'  :  9,
'W'  :  10,
'H'  :  11,
'A'  :  12,
'T'  :  13,
'R'  :  14,
'L'  :  15,
'J'  :  16,
'j'  :  17,
'u'  :  18,
's'  :  19,
't'  :  20,
'i'  :  21,
'n'  :  22,
'b'  :  23,
'e'  :  24,
'r'  :  25,
'a'  :  26,
'f'  :  27,
'o'  :  28,
'd'  :  29,
'y'  :  30,
'p'  :  31,
'h'  :  32,
'P'  :  33,
'm'  :  34,
'l'  :  35,
'c'  :  36,
'Q'  :  37,
'Z'  :  38,
'B'  :  39,
'z'  :  40,
'v'  :  41,
'g'  :  42,
'k'  :  43,
'w'  :  44,
'Y'  :  45,
'x'  :  46,
'K'  :  47,
'V'  :  48,
'X'  :  49,
'q'  :  50,
'G'  :  51,
'á'  :  52,
'ñ'  :  53,
'Ú'  :  54,
'í'  :  55,
'è'  :  56,
'ó'  :  57,
'ü'  :  58,
'é'  :  59,
'ç'  :  60,
'ã'  :  61,
'à'  :  62,
'ā'  :  63,
'ò'  :  64,
'б'  :  65,
'а'  :  66,
'р'  :  67,
'с'  :  68,
'е'  :  69,
'л'  :  70,
'о'  :  71,
'н'  :  72,
'É'  :  73,
'º'  :  74,
'Ó'  :  75}

# %%
a =[-1.8949014024,-2.1520386927,-2.2976864469,-2.2002727093,-2.2668840069,-2.3787196978,-2.4371457223,-1.9287506891,-1.9987616152,-2.3589306490,-2.2943392667,-2.2960096321,-2.0622752290,-2.0098760570,-2.2223018742,-2.1152022576,-2.3290319136,-2.2056761318,-1.5342005242,-1.3093500596,-1.1013536203,-1.2341128353,-1.2644649675,-1.7038949430,-1.0219497163,-1.3365913877,-1.1189153831,-1.8477174382,-1.1400128572,-1.6148032625,-1.6500159948,-1.6701383583,-1.433800098,-2.2731896637,-1.6399243609,-1.4068429169,-1.5980449396,-3.0716577374,-2.9212718785,-2.3027560899,-2.3183300707,-2.0403653791,-1.7769128656,-1.9223324273,-1.8342180094,-2.5782076991,-2.5413549740,-2.6827973866,-2.4418030804,-2.8379907216,-2.7079809326,-2.3787196978,-3.7324233890,-3.8350857309,-4.5340557350,-3.5798132258,-4.0569344805,-3.6132369813,-4.5340557350,-3.7324233890,-4.0569344805,-4.1660789499,-3.9697843048,-4.5340557350,-4.1660789499,-4.5340557350,-4.3122069855,-4.5340557350,-4.5340557350,-4.5340557350,-4.5340557350,-4.5340557350,-4.5340557350,-4.3122069855,-4.5340557350,-4.5340557350,]

# %%
x = np.asarray(list(dict0.values()))
# x = np.append(x, (x.shape[0]))
y = a
fig = plt.figure()
fig.set_size_inches(15, 3)
area = (30 * np.random.rand(x.shape[0]))**2
colors = np.random.rand(x.shape[0])
plt.title('enModel')
plt.xlabel('Alphabets')
plt.ylabel('Probability of alphabet')
plt.scatter(x, y, s=area, c=colors, alpha=0.9)
plt.xticks(x, list(dict0.keys()))
plt.tick_params(axis='x', which='minor', labelsize=10, width = 5)
